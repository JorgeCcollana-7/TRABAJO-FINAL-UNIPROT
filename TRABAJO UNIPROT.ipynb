# %% [markdown]
# **INTEGRANTES**
# **JORGE CCOLLANA**
# **JHOSEP PALOMINO**
# **ELIAN AYALA**
# **PAOLA ROMERO SOLANO**
#
# **DE PREFERENCIA ABRIR LA PAGINA WEB UNIPROT**

# %%
import openpyxl #es un paquete para leer archivos xlsx
import pandas as pd           #Para la creacion de tablas
import requests #es una paquete para decodificar archivos HTTP
from bs4 import BeautifulSoup as b  #extraer archivos de HTML
import re #codifica expresiones regulares
from openpyxl import load_workbook #ayuda a abrir un trabajo en excel

wb = openpyxl.load_workbook('02 Ch Genes ordenados con vecinos.xlsx')
# Primero vemos los nombres de las hojas que tiene el libro
# Devuelve una lista de python
hojas = wb.get_sheet_names()
hojas
# Out:
# <ipython-input-1-a8b940f2cec6>:11: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   hojas = wb.get_sheet_names()
# ['Información',
#  'C1 Milagros',
#  'C2 Wilmer',
#  'C3 Gisell',
#  'C4 Jerica',
#  'C5 Manuel',
#  'C6 Jerica',
#  'C7 Mariana',
#  'C8 Rosha',
#  'C9 Jerica',
#  'C10 Lucero',
#  'C11 Nicole',
#  'C12 Gisell',
#  'C13 Lucero',
#  'C14 Wilmer',
#  'C15Milagros',
#  'C16',
#  'C17',
#  'C18',
#  'Hoja 20',
#  'Hoja 21',
#  'Hoja 22',
#  'Hoja 23']

# %%
gen_hojas=hojas[2:14]# crea una variable eligiendo solo las hojas
gen_hojas
# Out:
# ['C2 Wilmer',
#  'C3 Gisell',
#  'C4 Jerica',
#  'C5 Manuel',
#  'C6 Jerica',
#  'C7 Mariana',
#  'C8 Rosha',
#  'C9 Jerica',
#  'C10 Lucero',
#  'C11 Nicole',
#  'C12 Gisell',
#  'C13 Lucero']

# %%
gen_lista=[]#se crea una lista vacía 
for i in gen_hojas:
    excel_gen = pd.read_excel('02 Ch Genes ordenados con vecinos.xlsx',sheet_name=i)#se lee el archivo excel pero con todas las hojas
    rows_gen=excel_gen.iloc[1:6,4]#elige de la fila 1 hasta la fila 5 de la columna 4 (gen abrev)
    gen_excel=list(rows_gen)#convierte en lista la variable rows_gen
    
    for i in gen_excel:
        gen_lista.append(i)#guarda cada gen en la lista vacía

# %%
gen_lista
# Out:
# ['LOC106503629',
#  'C2H1orf64',
#  'CLCNKA',
#  'HSPB7',
#  'FAM131C',
#  'LOC106503868',
#  'LOC108633797',
#  'LOC106503869',
#  'LOC106503865',
#  'LOC108633799',
#  'RNF32',
#  'LOC106502075',
#  'SHH',
#  'RBM33',
#  'CNPY1',
#  'NCKAP1L',
#  'GTSF1',
#  'ITGA5',
#  'ZNF385A',
#  'GPR84',
#  'GPRIN3',
#  'TIGD2',
#  'FAM13A',
#  'HERC3',
#  'NAP1L5',
#  'FBXL17',
#  'TRNAS-GGA',
#  'LOC102184996',
#  'EFNA5',
#  'LOC106502373',
#  'LOC102182592',
#  'SLC24A2',
#  'ACER2',
#  'RPS6',
#  'DENND4C',
#  'TRNAL-CAA',
#  'LOC102189482',
#  'OSTM1',
#  'SEC63',
#  'SCML4',
#  'EIF3J',
#  'CTDSPL2',
#  'LOC108636916',
#  'GOLM2',
#  'RPS6KA5',
#  'TRNAW-CCA',
#  'LOC102171344',
#  'LOC102171160',
#  'BCL2L11',
#  'ACOXL',
#  'TRNAC-GCA',
#  'LOC102168554',
#  'TMTC4',
#  'GGACT',
#  'PCCA',
#  'LOC108637349',
#  'SPTLC3',
#  'ISM1',
#  'TASP1\t',
#  'ESF1']

# %%
gen_hircus_capra=[['Gen', 'Entry', 'Entryname' , 'Protein', 'Gene', 'Organism', 
                 'Status', 'GO_Biological_process']]# creando una variable con las columnas pedidas de acuerdo al trabajo.

for Gen in gen_lista: 
    url = (f"https://www.uniprot.org/uniprot/?query={Gen}+capra+hircus&sort=score")
    #se crea un url con cada gen mas capra hircus en un ciclo for de la lista "gen lista"
    html = requests.get(url)#obtener los datos de la pagina
    soup = b(html.content, 'html.parser')#analiza el archivo de texto formateado en html
    
    if 'Sorry, no results found for your search term.' in str(soup.text):
        link_gen=[Gen, '', '' , '', '', '', '', '']
        # si no encuentra los datos que se necesita entonces por en blanco a la lista y agregalo en una fila
        

    else: #Sino entonces agrega todo los datos en el Reporte

        #Busqueda de la columna Entry
        Entry=soup.find('tr',class_="entry selected-row").a.text
        #Este codigo encontrar la etiqueta <tr> y su clase "entry selected-row", extrae la informacion de la etiqueta a y extrae el texto de la referencia.

        
        #Busqueda de la columna Entryname
        Entryname=soup.find('tr',class_="entry selected-row").find_all('td')[2].text
        #Este codigo encontrara la etiqueta <tr> y su clase "entry selected-row"; extrayendo todos los texto 
        # de la posicion [2] de todas las etiquetas <td>
        url_entry= (f"https://www.uniprot.org/uniprot/{Entry}") #Usamos la informacion obtenida en 'entry', para obtener la información de la siguiente pagina a webscrapear
        html_entry = requests.get(url_entry)
        soup_entry = b(html_entry.content, 'html.parser')
        
        Protein=soup_entry.find('div', id='content-protein').text
        #Encuentra la primera etiqueta <div> con id 'content-gene' y extrae el texto
        Gene=soup_entry.find('div', id='content-gene').text
        #Encuentra la etiqueta y extrae el texto
        Organism=soup_entry.find('div', id='content-organism').text
        #Encuentra la primera etiqueta y extrae el texto de la primera etiqueta <span>
        Status=soup_entry.find('div',id="content-status").span.text
        
        GO_gen=soup_entry.find('ul', class_="noNumbering biological_process")
        #Si no encuentra nada en GO_gen, GO_Biological_process se colocara como una cadena vacia
        if GO_gen is None:
             GO_Biological_process=' '
         #En caso contrario se encuentre resultados
        else:
            #si llega a  econtrar,  empieza a buscar  todas las etiquetas <a> que terminen en 'Display-GO-Term'
            GO_descripcion=GO_gen.find_all('a', onclick="window.ga('UniProt-Entry-View', 'click', 'Display-GO-Term');")
            GO_Biological_process='' #Esta linea  crea una  cadena vacia a la cual se apendizara todo el texto encontrado en GO_descripcion
            #Hicimos un  bucle para apendizar el texto para cada GO_descripcion encontrado
            for x in GO_descripcion: #Se crea el bucle Go_descripcion y llenara con lo encontrado
                 GO_Biological_process+=x.text+','
        
        link_gen=[Gen, Entry, Entryname , Protein, Gene, Organism, Status, GO_Biological_process] # Invoca todas las variables asignadas para agregarle los datos 
    gen_hircus_capra.append(link_gen)

# %%
import numpy as np
data=pd.DataFrame(gen_hircus_capra) #Ahora los trabajaran como data frame
data.replace(to_replace=[""], value=np.nan, inplace=True) #A los espacion que no tengan datos les  estamos reemplazando con el valor "NaN"
data
# Out:
#                0           1                 2  \
# 0            Gen       Entry         Entryname
# 1   LOC106503629         NaN               NaN
# 2      C2H1orf64         NaN               NaN
# 3         CLCNKA  A0A452G531  A0A452G531_CAPHI
# 4          HSPB7  A0A452G662  A0A452G662_CAPHI
# ..           ...         ...               ...
# 56  LOC108637349         NaN               NaN
# 57        SPTLC3  A0A452DVM3  A0A452DVM3_CAPHI
# 58          ISM1  A0A452E9N3  A0A452E9N3_CAPHI
# 59       TASP1\t  A0A452FXP0  A0A452FXP0_CAPHI
# 60          ESF1  A0A452FHK7  A0A452FHK7_CAPHI
#
#                                                     3       4  \
# 0                                             Protein    Gene
# 1                                                 NaN     NaN
# 2                                                 NaN     NaN
# 3                            Chloride channel protein  CLCNKA
# 4   Submitted name: Heat shock protein family B (s...   HSPB7
# ..                                                ...     ...
# 56                                                NaN     NaN
# 57  Submitted name: Serine palmitoyltransferase lo...  SPTLC3
# 58                          Submitted name: Isthmin 1    ISM1
# 59                          Submitted name: Taspase 1   TASP1
# 60  Submitted name: ESF1 nucleolar pre-rRNA proces...    ESF1
#
#                       5           6  \
# 0              Organism      Status
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3   Capra hircus (Goat)  Unreviewed
# 4   Capra hircus (Goat)  Unreviewed
# ..                  ...         ...
# 56                  NaN         NaN
# 57  Capra hircus (Goat)  Unreviewed
# 58  Capra hircus (Goat)  Unreviewed
# 59  Capra hircus (Goat)  Unreviewed
# 60  Capra hircus (Goat)  Unreviewed
#
#                                                     7
# 0                               GO_Biological_process
# 1                                                 NaN
# 2                                                 NaN
# 3                                 chloride transport,
# 4                                  heart development,
# ..                                                ...
# 56                                                NaN
# 57                    sphingoid biosynthetic process,
# 58
# 59  positive regulation of transcription, DNA-temp...
# 60                                   rRNA processing,
#
# [61 rows x 8 columns]

# %%
data.to_excel("Reporte.xlsx",index=False,header=None) #Se esta creando un excel con la dataframe  "data" que nos da el resultado y con header none elimina la primera fila.
